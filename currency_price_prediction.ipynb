# %%
import datetime
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import the data
df=pd.read_csv("USD.csv")
df
# Out:
#             Date       Open       High        Low      Close  Adj Close
# 0     12/22/2003  45.417000  45.505001  45.390999  45.452000  45.452000
# 1     12/23/2003  45.446999  45.549000  45.326000  45.389000  45.389000
# 2     12/24/2003  45.390999  45.533001  45.360001  45.442001  45.442001
# 3     12/25/2003  45.438000  45.456001  45.296001  45.445000  45.445000
# 4     12/26/2003  45.423000  45.457001  45.396000  45.441002  45.441002
# ...          ...        ...        ...        ...        ...        ...
# 4582   7/14/2021  74.659500  74.869003  74.456001  74.659103  74.659103
# 4583   7/15/2021  74.454002  74.562798  74.438004  74.469101  74.469101
# 4584   7/16/2021  74.537903  74.800003  74.496498  74.537003  74.537003
# 4585   7/19/2021  74.631897  75.020401  74.631104  74.631798  74.631798
# 4586   7/20/2021  74.850998  74.949997  74.529999  74.529999  74.529999
#
# [4587 rows x 6 columns]

# %%
#data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4587 entries, 0 to 4586
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4587 non-null   object
#  1   Open       4535 non-null   float64
#  2   High       4535 non-null   float64
#  3   Low        4535 non-null   float64
#  4   Close      4535 non-null   float64
#  5   Adj Close  4535 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 215.1+ KB

# %%
df.shape
# Out:
# (4587, 6)

# %%
type(df.Date[0])
# Out:
# str

# %%
#parse by date
df=pd.read_csv("USD.csv", parse_dates=["Date"])
df
# Out:
#            Date       Open       High        Low      Close  Adj Close
# 0    2003-12-22  45.417000  45.505001  45.390999  45.452000  45.452000
# 1    2003-12-23  45.446999  45.549000  45.326000  45.389000  45.389000
# 2    2003-12-24  45.390999  45.533001  45.360001  45.442001  45.442001
# 3    2003-12-25  45.438000  45.456001  45.296001  45.445000  45.445000
# 4    2003-12-26  45.423000  45.457001  45.396000  45.441002  45.441002
# ...         ...        ...        ...        ...        ...        ...
# 4582 2021-07-14  74.659500  74.869003  74.456001  74.659103  74.659103
# 4583 2021-07-15  74.454002  74.562798  74.438004  74.469101  74.469101
# 4584 2021-07-16  74.537903  74.800003  74.496498  74.537003  74.537003
# 4585 2021-07-19  74.631897  75.020401  74.631104  74.631798  74.631798
# 4586 2021-07-20  74.850998  74.949997  74.529999  74.529999  74.529999
#
# [4587 rows x 6 columns]

# %%
#cheak Date type
type(df.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4587 entries, 0 to 4586
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4587 non-null   datetime64[ns]
#  1   Open       4535 non-null   float64
#  2   High       4535 non-null   float64
#  3   Low        4535 non-null   float64
#  4   Close      4535 non-null   float64
#  5   Adj Close  4535 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 215.1 KB

# %% [markdown]
# #set Date as index colunm

# %%
df=pd.read_csv("USD.csv",parse_dates=["Date"],index_col=['Date'])

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close
# Date
# 2003-12-22  45.417000  45.505001  45.390999  45.452000  45.452000
# 2003-12-23  45.446999  45.549000  45.326000  45.389000  45.389000
# 2003-12-24  45.390999  45.533001  45.360001  45.442001  45.442001
# 2003-12-25  45.438000  45.456001  45.296001  45.445000  45.445000
# 2003-12-26  45.423000  45.457001  45.396000  45.441002  45.441002

# %%
df.index
# Out:
# DatetimeIndex(['2003-12-22', '2003-12-23', '2003-12-24', '2003-12-25',
#                '2003-12-26', '2003-12-29', '2003-12-30', '2003-12-31',
#                '2004-01-01', '2004-01-02',
#                ...
#                '2021-07-07', '2021-07-08', '2021-07-09', '2021-07-12',
#                '2021-07-13', '2021-07-14', '2021-07-15', '2021-07-16',
#                '2021-07-19', '2021-07-20'],
#               dtype='datetime64[ns]', name='Date', length=4587, freq=None)

# %%
df.sort_index(inplace=True) # data sort by index base

# %%
df.index
# Out:
# DatetimeIndex(['2003-12-22', '2003-12-23', '2003-12-24', '2003-12-25',
#                '2003-12-26', '2003-12-29', '2003-12-30', '2003-12-31',
#                '2004-01-01', '2004-01-02',
#                ...
#                '2021-07-07', '2021-07-08', '2021-07-09', '2021-07-12',
#                '2021-07-13', '2021-07-14', '2021-07-15', '2021-07-16',
#                '2021-07-19', '2021-07-20'],
#               dtype='datetime64[ns]', name='Date', length=4587, freq=None)

# %%
#one month repsentation
df['2021-07']
# Out:
#                  Open       High        Low      Close  Adj Close
# Date
# 2021-07-01  74.371101  74.628502  74.310997  74.371002  74.371002
# 2021-07-02  74.553596  74.899002  74.464996  74.544998  74.544998
# 2021-07-05  74.481903  74.586998  74.203003  74.481796  74.481796
# 2021-07-06  74.317802  74.771301  74.242500  74.317802  74.317802
# 2021-07-07  74.761200  74.853302  74.554497  74.762901  74.762901
# 2021-07-08  74.821899  74.866203  74.639999  74.821899  74.821899
# 2021-07-09  74.721497  74.911003  74.473396  74.721397  74.721397
# 2021-07-12  74.490601  74.657997  74.275398  74.490501  74.490501
# 2021-07-13  74.541702  74.675797  74.399498  74.541702  74.541702
# 2021-07-14  74.659500  74.869003  74.456001  74.659103  74.659103
# 2021-07-15  74.454002  74.562798  74.438004  74.469101  74.469101
# 2021-07-16  74.537903  74.800003  74.496498  74.537003  74.537003
# 2021-07-19  74.631897  75.020401  74.631104  74.631798  74.631798
# ...

# %%
df['2021-07'].Close
# Out:
# Date
# 2021-07-01    74.371002
# 2021-07-02    74.544998
# 2021-07-05    74.481796
# 2021-07-06    74.317802
# 2021-07-07    74.762901
# 2021-07-08    74.821899
# 2021-07-09    74.721397
# 2021-07-12    74.490501
# 2021-07-13    74.541702
# 2021-07-14    74.659103
# 2021-07-15    74.469101
# 2021-07-16    74.537003
# 2021-07-19    74.631798
# 2021-07-20    74.529999
# Name: Close, dtype: float64

# %%
#cheak mean a for one month
df['2021-07'].Close.mean()
# Out:
# 74.56292871428572

# %%
df['2021-07'].Close.median()
# Out:
# 74.5393525

# %%
df['2021-07'].Close.mode()
# Out:
# 0     74.317802
# 1     74.371002
# 2     74.469101
# 3     74.481796
# 4     74.490501
# 5     74.529999
# 6     74.537003
# 7     74.541702
# 8     74.544998
# 9     74.631798
# 10    74.659103
# 11    74.721397
# 12    74.762901
# 13    74.821899
# dtype: float64

# %%
#single day high close
df.loc['2019-08-02']
# Out:
# Open         69.296997
# High         69.800003
# Low          69.007500
# Close        69.297203
# Adj Close    69.297203
# Name: 2019-08-02 00:00:00, dtype: float64

# %%
#time range
df['2019-07-09':'2019-08-09']
# Out:
#                  Open       High        Low      Close  Adj Close
# Date
# 2019-07-09  68.558998  68.849998  68.507004  68.849998  68.849998
# 2019-07-10  68.555496  68.764999  68.292503  68.764999  68.764999
# 2019-07-11  68.508102  68.529999  68.202301  68.367599  68.367599
# 2019-07-12  68.443001  68.682999  68.356499  68.669998  68.669998
# 2019-07-15  68.550499  68.591003  68.301498  68.550301  68.550301
# 2019-07-16  68.532997  68.750000  68.505997  68.747498  68.747498
# 2019-07-17  68.681297  68.894997  68.603996  68.894997  68.894997
# 2019-07-18  68.785896  69.012497  68.700302  68.786003  68.786003
# 2019-07-19  68.785301  68.934502  68.601501  68.849998  68.849998
# 2019-07-22  68.852997  69.205002  68.830002  68.830002  68.830002
# 2019-07-23  69.160004  69.192497  68.900002  69.160004  69.160004
# 2019-07-24  69.019997  69.349998  68.922600  69.019997  69.019997
# 2019-07-25  68.981102  69.184998  68.882797  69.184998  69.184998
# ...

# %%
df.Close.resample("M").count()
# Out:
# Date
# 2003-12-31     8
# 2004-01-31    22
# 2004-02-29    20
# 2004-03-31    23
# 2004-04-30    21
#               ..
# 2021-03-31    23
# 2021-04-30    22
# 2021-05-31    21
# 2021-06-30    22
# 2021-07-31    14
# Freq: M, Name: Close, Length: 212, dtype: int64

# %%
#resampling by month
list(df.Close.resample("M"))
# Out:
# [(Timestamp('2003-12-31 00:00:00', freq='M'), Date
#   2003-12-22    45.452000
#   2003-12-23    45.389000
#   2003-12-24    45.442001
#   2003-12-25    45.445000
#   2003-12-26    45.441002
#   2003-12-29    45.549000
#   2003-12-30    45.499001
#   2003-12-31    45.529999
#   Name: Close, dtype: float64),
#  (Timestamp('2004-01-31 00:00:00', freq='M'), Date
#   2004-01-01    45.527000
#   2004-01-02    45.603001
#   2004-01-05    45.466000
#   2004-01-06    45.549000
#   2004-01-07    45.387001
#   2004-01-08    45.467999
#   2004-01-09    45.351002
#   2004-01-12    45.344002
#   2004-01-13    45.313000
#   2004-01-14    45.327999
#   2004-01-15    45.348999
#   2004-01-16    45.325001
#   2004-01-19    45.331001
#   2004-01-20    45.327999
#   2004-01-21    45.306999
#   2004-01-22    45.320999
#   2004-01-23    45.243999
#   2004-01-26    45.227001
#   2004-01-27    45.271000
#   2004-01-28    45.252998
#   2004-01-29    45.271000
#   2004-01-30    45.004002
# ...

# %%
df.Close.resample("Y").mean() #Yearly mean pf close
# Out:
# Date
# 2003-12-31    45.468375
# 2004-12-31    45.188604
# 2005-12-31    44.003753
# 2006-12-31    45.183561
# 2007-12-31    41.192248
# 2008-12-31    43.464831
# 2009-12-31    48.283335
# 2010-12-31    45.621969
# 2011-12-31    46.562903
# 2012-12-31    53.404276
# 2013-12-31    58.528904
# 2014-12-31    60.973456
# 2015-12-31    64.124460
# 2016-12-31    67.166366
# 2017-12-31    65.109593
# 2018-12-31    68.451756
# 2019-12-31    70.448282
# 2020-12-31    74.222812
# 2021-12-31    73.460803
# Freq: A-DEC, Name: Close, dtype: float64

# %%
# %matplotlib inline
#month wise close price
plt.figure(figsize=(18,6))
plt.title('Montly Close Price ')
df.Close.resample("M").median().plot()
plt.xlabel('Year', fontsize=18)
plt.ylabel('Close Price', fontsize=18)
# Out:
# Text(0, 0.5, 'Close Price')

# %%
# %matplotlib inline
#day wise 
price_close=df['Close']
plt.figure(figsize=(18,6))
plt.title('Day wise Close Price History')
plt.plot(df.index,price_close)
plt.xlabel('Year', fontsize=18)
plt.ylabel('Close Price', fontsize=18)
plt.show()

# %%
#resapleing on bussiness day
price_close=df['Close']
plt.figure(figsize=(18,6))
plt.title('Bussiness-Day wise Close Price')
df.Close.resample("B").mean().plot()

# %%
#resample by quatry
price_close=df['Close']
plt.figure(figsize=(18,6))
plt.title('Bussiness-Day wise Close Price')
df.Open.resample('Q').mean().plot()

# %% [markdown]
# #cross validation for date range

# %%
df.index
# Out:
# DatetimeIndex(['2003-12-22', '2003-12-23', '2003-12-24', '2003-12-25',
#                '2003-12-26', '2003-12-29', '2003-12-30', '2003-12-31',
#                '2004-01-01', '2004-01-02',
#                ...
#                '2021-07-07', '2021-07-08', '2021-07-09', '2021-07-12',
#                '2021-07-13', '2021-07-14', '2021-07-15', '2021-07-16',
#                '2021-07-19', '2021-07-20'],
#               dtype='datetime64[ns]', name='Date', length=4587, freq=None)

# %%
# index rang length=4587
pd.date_range('2003-12-22','2021-07-20' ,freq='B')
#date_range length = 4587
# Out:
# DatetimeIndex(['2003-12-22', '2003-12-23', '2003-12-24', '2003-12-25',
#                '2003-12-26', '2003-12-29', '2003-12-30', '2003-12-31',
#                '2004-01-01', '2004-01-02',
#                ...
#                '2021-07-07', '2021-07-08', '2021-07-09', '2021-07-12',
#                '2021-07-13', '2021-07-14', '2021-07-15', '2021-07-16',
#                '2021-07-19', '2021-07-20'],
#               dtype='datetime64[ns]', length=4587, freq='B')

# %% [markdown]
# #TO cheak the null value

# %%
import missingno as msno
#for cheak null values
msno.matrix(df)
plt.show()

# %%
#forward fill
df=df.fillna(method='ffill')

# %%
msno.matrix(df)
plt.show()

# %% [markdown]
# **bold text**#plot after null value  removing

# %%
price_close=df['Close']
plt.figure(figsize=(18,6))
plt.title('Bussiness-Day wise Close Price')
df.Close.plot()

# %% [markdown]
# #box plot

# %%
fig, ax = plt.subplots(figsize=(16,8))
sns.boxplot(
   data =df ,
   x=df.index,
   y=df.Close
  )

# %% [markdown]
# componets of Time series

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse
import matplotlib.pyplot as plt

# Multiplicative Decomposition 
result_mul = seasonal_decompose(df['Close'], model='multiplicative', extrapolate_trend='freq')

# Additive Decomposition
result_add = seasonal_decompose(df['Close'], model='additive', extrapolate_trend='freq')

# Plot
plt.rcParams.update({'figure.figsize': (5,5)})
result_mul.plot().suptitle('Multiplicative Decompose', fontsize=22)
result_add.plot().suptitle('Additive Decompose', fontsize=22)
plt.show()

# %%
#cheak the stationary
from statsmodels.tsa.stattools import adfuller
# ADF Test
#Augmented Dickey–Fuller test
result = adfuller(df.Close.values, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'p-value: {result[1]}')
for key, value in result[4].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# ADF Statistic: -0.15407661095671513
# p-value: 0.9437787547835841
# Critial Values:
#    1%, -3.4317782837918727
# Critial Values:
#    5%, -2.8621711342851617
# Critial Values:
#    10%, -2.5671059557268925

# %% [markdown]
# #ADF Statistic: -0.15407 > any critical value so
# #IT is non_statnary
# #make statnary using substract moving avrage

# %%
df['RA'] = df.Close.rolling(12,min_periods=2).mean() # 12 days moving avrage

# %%
plt.figure(figsize=(12,6))
df['Close'].plot(),df['RA'].plot()
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f30a93833d0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f30a93833d0>)

# %%
df['RA_detrend'] = df.Close - df.RA

# %%
df['RA_detrend'].head()
# Out:
# Date
# 2003-12-22         NaN
# 2003-12-23   -0.031500
# 2003-12-24    0.014334
# 2003-12-25    0.013000
# 2003-12-26    0.007201
# Name: RA_detrend, dtype: float64

# %%
df['RA_detrend'].plot()

# %%
result = adfuller(df.RA_detrend.values[1:], autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'p-value: {result[1]}')
for key, value in result[4].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# ADF Statistic: -11.653242766826157
# p-value: 2.013686288974434e-21
# Critial Values:
#    1%, -3.431784865122899
# Critial Values:
#    5%, -2.8621740417619224
# Critial Values:
#    10%, -2.5671075035106954

# %% [markdown]
# # ADF Statistic: -11.6532 < Critial Values
# #it is make Stationery

# %%
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error
from math import sqrt

# %%
def ts_train_test_split(X,per=0.90):
    size = int(len(X) * per)
    train, test = X[0:size], X[size:len(X)]
    return train,test

# %%
train,test = ts_train_test_split(df.loc['2003-12-23':,'RA'],per=0.90)

# %%
train.head()
# Out:
# Date
# 2003-12-23    45.420500
# 2003-12-24    45.427667
# 2003-12-25    45.432000
# 2003-12-26    45.433801
# 2003-12-29    45.453000
# Name: RA, dtype: float64

# %%
len(train),len(test)
# Out:
# (4127, 459)

# %%
train.index,test.index
# Out:
# (DatetimeIndex(['2003-12-23', '2003-12-24', '2003-12-25', '2003-12-26',
#                 '2003-12-29', '2003-12-30', '2003-12-31', '2004-01-01',
#                 '2004-01-02', '2004-01-05',
#                 ...
#                 '2019-10-03', '2019-10-04', '2019-10-07', '2019-10-08',
#                 '2019-10-09', '2019-10-10', '2019-10-11', '2019-10-14',
#                 '2019-10-15', '2019-10-16'],
#                dtype='datetime64[ns]', name='Date', length=4127, freq=None),
#  DatetimeIndex(['2019-10-17', '2019-10-18', '2019-10-21', '2019-10-22',
#                 '2019-10-23', '2019-10-24', '2019-10-25', '2019-10-28',
#                 '2019-10-29', '2019-10-30',
#                 ...
#                 '2021-07-07', '2021-07-08', '2021-07-09', '2021-07-12',
#                 '2021-07-13', '2021-07-14', '2021-07-15', '2021-07-16',
#                 '2021-07-19', '2021-07-20'],
#                dtype='datetime64[ns]', name='Date', length=459, freq=None))

# %%
# Manually Configured ARIMA
model = ARIMA(train.values, order=(1,2,1)) # order is p,d,q
model_fit = model.fit( )
output = model_fit.predict(dynamic=False)
print(model_fit.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
#                              ARIMA Model Results
# ...
# Dep. Variable:                   D2.y   No. Observations:                 4125
# ...

# %%
output_1 = model_fit.forecast(len(test))
#Root Mean Square Error
print("MSE  = ", mean_squared_error(test,output_1[0]))
print("Mean Square Log Error = ", mean_squared_log_error(test,output_1[0]))
print("RMSE  = ",sqrt(mean_squared_error(test,output_1[0])))
# Out:
# MSE  =  120.00677453210862
# Mean Square Log Error =  0.02595984701409812
# RMSE  =  10.954760359410361

# %%
print('expected=',test)
# Out:
# expected= Date
# 2019-10-17    71.602209
# 2019-10-18    71.546376
# 2019-10-21    71.457834
# 2019-10-22    71.375543
# 2019-10-23    71.290751
#                 ...
# 2021-07-14    74.523842
# 2021-07-15    74.539150
# 2021-07-16    74.559934
# 2021-07-19    74.581667
# 2021-07-20    74.580417
# Name: RA, Length: 459, dtype: float64

# %%
#predict value
print('predicted=',output_1[0])
# Out:
# predicted= [71.60900913 71.57699727 71.54490858 71.51281844 71.48071795 71.44860818
#  71.41648898 71.38436039 71.35222239 71.32007498 71.28791817 71.25575196
#  71.22357635 71.19139133 71.15919691 71.12699308 71.09477985 71.06255722
#  71.03032518 70.99808374 70.9658329  70.93357265 70.901303   70.86902394
#  70.83673548 70.80443762 70.77213035 70.73981368 70.70748761 70.67515213
#  70.64280725 70.61045296 70.57808927 70.54571618 70.51333369 70.48094179
#  70.44854048 70.41612977 70.38370966 70.35128015 70.31884123 70.28639291
#  70.25393518 70.22146805 70.18899152 70.15650558 70.12401024 70.0915055
#  70.05899135 70.0264678  69.99393484 69.96139248 69.92884072 69.89627955
#  69.86370898 69.83112901 69.79853963 69.76594085 69.73333266 69.70071508
#  69.66808808 69.63545169 69.60280589 69.57015068 69.53748608 69.50481207
#  69.47212865 69.43943583 69.40673361 69.37402198 69.34130096 69.30857052
#  69.27583069 69.24308144 69.2103228  69.17755475 69.1447773  69.11199045
# ...

# %%
#pridiction plot
#fig, ax = plt.subplots(figsize=(14,8))
ax.set_title("predicted price")
ax.set_xlabel('price')
ax.set_ylabel('date')
model_fit.plot_predict(len(test),ax=ax )

# %%
# ACF and PACF (Auto corealation / paratial correlation)
import statsmodels.api as sm
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(model_fit.resid, lags=20, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(model_fit.resid, lags=20, ax=ax2)

# %% [markdown]
# #auto arima to predict best parameters

# %%
#Auto Arima
# !pip install pmdarima

# %%
#fine tune by autoarima
import pmdarima as pm
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error
from math import sqrt
from pmdarima.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt

y = df['Close']

train, test = train_test_split(y, train_size=4127)

# %%
train.shape,test.shape
# Out:
# ((4127,), (460,))

# %%
test.head()
# Out:
# Date
# 2019-10-16    71.760002
# 2019-10-17    71.620003
# 2019-10-18    71.422501
# 2019-10-21    71.029999
# 2019-10-22    71.105003
# Name: Close, dtype: float64

# %%
#p is the order of the Auto Regressive (AR) term. It refers to the number of lags of Y to be used as predictors.
#d is  'Auto Regressive’ in ARIMA
#q is the order of the Moving Average (MA) term. 
model_autoARIMA =pm.auto_arima(train, start_p=0, start_q=0,
test='adf',       # use adftest to find optimal 'd'
max_p=3, max_q=3, # maximum p and q
m=1,              # frequency of series
d=None,           # let model determine 'd'
seasonal=True,   #  Seasonality 
error_action='ignore',  
suppress_warnings=True, 
stepwise=True)
print(model_autoARIMA.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                 4127
# Model:               SARIMAX(1, 1, 0)   Log Likelihood                -561.550
# Date:                Thu, 30 Sep 2021   AIC                           1129.101
# Time:                        09:49:35   BIC                           1148.076
# Sample:                             0   HQIC                          1135.816
#                                - 4127
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0073      0.004      1.643      0.100      -0.001       0.016
# ar.L1         -0.1571      0.006    -27.386      0.000      -0.168      -0.146
# sigma2         0.0769      0.001    109.213      0.000       0.075       0.078
# ...

# %%
model = ARIMA(train, order=(1, 1, 0))
fitted = model.fit(disp=-1)
print(fitted.summary())
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:                D.Close   No. Observations:                 4126
# Model:                 ARIMA(1, 1, 0)   Log Likelihood                -561.550
# Method:                       css-mle   S.D. of innovations              0.277
# Date:                Thu, 30 Sep 2021   AIC                           1129.101
# Time:                        09:49:36   BIC                           1148.076
# Sample:                    12-23-2003   HQIC                          1135.816
#                          - 10-15-2019
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0063      0.004      1.685      0.092      -0.001       0.014
# ar.L1.D.Close    -0.1570      0.015    -10.210      0.000      -0.187      -0.127
#                                     Roots
# ...

# %%
#fc = forcast ,stand error=se , confidence interval =conf
fc, se, conf = fitted.forecast( len(test), alpha=0.05)  # alpha =95% confidence

# %%
fc.shape ,test.shape
# Out:
# ((460,), (460,))

# %%
#Root Mean Square Error
print("MSE  = ", mean_squared_error(test,fc))
print("Mean Square Log Error = ", mean_squared_log_error(test,fc))
print("RMSE  = ",sqrt(mean_squared_error(test,fc)))
# Out:
# MSE  =  3.2578260133980526
# Mean Square Log Error =  0.0005788380767263606
# RMSE  =  1.8049448782159672

# %%
import statsmodels.api as sm
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(fitted.resid, lags=20, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(fitted.resid, lags=20, ax=ax2)

# %%
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, color = 'blue', label='Actual  Price')
plt.plot(fc_series, color = 'orange',label='Predicted  Price')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.10)
plt.title('Rupee Price Prediction')
plt.xlabel('Time')
plt.ylabel('Actual  Price')
plt.show()

# %% [markdown]
# When Seasonality is  False

# %%
model_autoARIMA =pm.auto_arima(train, start_p=0, start_q=0,
test='adf',       # use adftest to find optimal 'd'
max_p=4, max_q=4, # maximum p and q
m=1,              # frequency of series
d=None,           # let model determine 'd'
seasonal=False,   # No Seasonality
start_P=0, 
D=0, 
trace=True,
error_action='ignore',  
suppress_warnings=True, 
stepwise=True)
print(model_autoARIMA.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1230.052, Time=0.39 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1129.101, Time=0.24 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1132.736, Time=0.83 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1230.131, Time=0.36 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=1130.834, Time=3.47 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1130.763, Time=1.41 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1132.903, Time=1.58 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=1129.938, Time=0.25 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[0] intercept
# Total fit time: 8.531 seconds
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                 4127
# Model:               SARIMAX(1, 1, 0)   Log Likelihood                -561.550
# Date:                Thu, 30 Sep 2021   AIC                           1129.101
# ...

# %%
model = ARIMA(train, order=(1, 1, 0))
fitted = model.fit(disp=-1)
print(fitted.summary())
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:                D.Close   No. Observations:                 4126
# Model:                 ARIMA(1, 1, 0)   Log Likelihood                -561.550
# Method:                       css-mle   S.D. of innovations              0.277
# Date:                Thu, 30 Sep 2021   AIC                           1129.101
# Time:                        09:50:20   BIC                           1148.076
# Sample:                    12-23-2003   HQIC                          1135.816
#                          - 10-15-2019
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0063      0.004      1.685      0.092      -0.001       0.014
# ar.L1.D.Close    -0.1570      0.015    -10.210      0.000      -0.187      -0.127
#                                     Roots
# ...

# %%
fc, se, conf = fitted.forecast(len(test), alpha=0.05)  # 95% confidence

# %%
#Root Mean Square Error
print("MSE  = ", mean_squared_error(test,fc))
print("Mean Square Log Error = ", mean_squared_log_error(test,fc))
print("RMSE  = ",sqrt(mean_squared_error(test,fc)))
# Out:
# MSE  =  3.2578260133980526
# Mean Square Log Error =  0.0005788380767263606
# RMSE  =  1.8049448782159672

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(fitted.resid, lags=20, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(fitted.resid, lags=20, ax=ax2)

# %%
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, color = 'blue', label='Actual  Price')
plt.plot(fc_series, color = 'orange',label='Predicted  Price')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.10)
plt.title('Rupee Price Prediction')
plt.xlabel('Time')
plt.ylabel('Actual  Price')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %% [markdown]
# # Apply SARIMA MODEL

# %%
#resampleing model montly
y = df.Close.resample("M").mean()
train, test = train_test_split(y, train_size=183)

# %%
y.shape,train.shape,test.shape,type(test)
# Out:
# ((212,), (183,), (29,), pandas.core.series.Series)

# %%
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error
from math import sqrt
model = sm.tsa.statespace.SARIMAX(train,order=(0,1,1),seasonal_order=(1,1,1,12))
result=model.fit()
# make your forecasts
forecasts_sarima= result.predict(start=184,end=212,dynamic=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/kalman_filter.py:2292: ValueWarning: Dynamic prediction specified to begin during out-of-sample forecasting period, and so has no effect.
#   ' effect.', ValueWarning)

# %%
forecasts_sarima.shape
# Out:
# (29,)

# %%
#Root Mean Square Error
print("MSE  = ", mean_squared_error(test,forecasts_sarima))
print("Mean Square Log Error = ", mean_squared_log_error(test,forecasts_sarima))
print("RMSE  = ",sqrt(mean_squared_error(test,forecasts_sarima)))
# Out:
# MSE  =  3.542844329043911
# Mean Square Log Error =  0.0006502170007307802
# RMSE  =  1.88224449236647

# %%
result.plot_diagnostics(figsize=(10,8))

# %%
# Visualize the forecasts (blue=train, green=forecasts)
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, color = 'blue', label='Actual  Price')
plt.plot(forecasts_sarima, color = 'red',label='Predicted  Price')
plt.title('Rupee Price Prediction (Montly)')
plt.xlabel('Time')
plt.ylabel('Actual  Price') 
plt.show()

# %% [markdown]
# #SARIMA MODEL date wise prediction (2021-01-01 - 2021-07-20)

# %%
#Date wise prediction
y_day = df.Close.iloc[-143:]
y_day.index
# data size
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-04', '2021-01-05', '2021-01-06',
#                '2021-01-07', '2021-01-08', '2021-01-11', '2021-01-12',
#                '2021-01-13', '2021-01-14',
#                ...
#                '2021-07-07', '2021-07-08', '2021-07-09', '2021-07-12',
#                '2021-07-13', '2021-07-14', '2021-07-15', '2021-07-16',
#                '2021-07-19', '2021-07-20'],
#               dtype='datetime64[ns]', name='Date', length=143, freq=None)

# %%
train, test = train_test_split(y_day, train_size=129)

# %%
# 6 months data in traindata and 1 month prediction
train.index,test.index
# Out:
# (DatetimeIndex(['2021-01-01', '2021-01-04', '2021-01-05', '2021-01-06',
#                 '2021-01-07', '2021-01-08', '2021-01-11', '2021-01-12',
#                 '2021-01-13', '2021-01-14',
#                 ...
#                 '2021-06-17', '2021-06-18', '2021-06-21', '2021-06-22',
#                 '2021-06-23', '2021-06-24', '2021-06-25', '2021-06-28',
#                 '2021-06-29', '2021-06-30'],
#                dtype='datetime64[ns]', name='Date', length=129, freq=None),
#  DatetimeIndex(['2021-07-01', '2021-07-02', '2021-07-05', '2021-07-06',
#                 '2021-07-07', '2021-07-08', '2021-07-09', '2021-07-12',
#                 '2021-07-13', '2021-07-14', '2021-07-15', '2021-07-16',
#                 '2021-07-19', '2021-07-20'],
#                dtype='datetime64[ns]', name='Date', freq=None))

# %%
model = sm.tsa.statespace.SARIMAX(train,order=(1,1,1),seasonal_order=(1,1,1,12))
result_day=model.fit()
# make your forecasts
forecasts_day= result_day.predict(start=129,end=142,dynamic=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)

# %%
result_day.plot_diagnostics(figsize=(10,8))

# %%
#Root Mean Square Error
print("MSE  = ", mean_squared_error(test,forecasts_day))
print("Mean Square Log Error = ", mean_squared_log_error(test,forecasts_day))
print("RMSE  = ",sqrt(mean_squared_error(test,forecasts_day)))
# Out:
# MSE  =  0.04305443931158124
# Mean Square Log Error =  7.54110940240579e-06
# RMSE  =  0.207495636849504

# %%
# Visualize the forecasts (blue=train, red=forecasts)
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, color = 'blue', label='Actual  Price')
plt.plot(forecasts_day, color = 'red',label='Predicted  Price')
plt.title('Rupee Price Prediction (2021-07-01 to 2021-07-20) ')
plt.xlabel('Time')
plt.ylabel('Actual  Price') 
plt.show()
